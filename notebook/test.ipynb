# %%
# !pip3 install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tabula-py
#   Downloading tabula_py-2.6.0-py3-none-any.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 11.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.21.6)
# Collecting distro
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.15.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.8.0 tabula-py-2.6.0

# %%
path = "/content/drive/Othercomputers/My MacBook Pro/data-science/projects/pools-dashboard/"

# %%
import pandas as pd
import tabula
import re
import numpy as np

# %%
def process(df):
    # rename
    # print('hi', df.columns.values)
    df = df.copy().reset_index()
    df_cols = list(df.columns)
    a = [re.sub('\\r|\&|\/|\.', '', x).strip() for x in df_cols]
    a = ["_".join(x.split()).lower() for x in a]
    df.columns = a

    # datatypes
    df['amount'] = df['amount'].str.split(' ').str[-1]
    df['payout_winnings'] = df['payout_winnings'].str.split(' ').str[-1]

    df['transaction_date_time'] = df['transaction_date_time'].str.split('\\r').str[0] + ' ' + \
                                  df['transaction_date_time'].str.split('\\r').str[1]
    df['draw_eventdate_time'] = df['draw_eventdate_time'].str.split('\\r').str[0] + ' ' + \
                                df['draw_eventdate_time'].str.split('\\r').str[1]
    df['status_receiptno'] = df['status_receiptno'].str.split('\\r').str[0]
    df['type'] = df['type'].str.split('\\r').str[0]

    df['amount'] = pd.to_numeric(df['amount'], errors='coerce')
    df['payout_winnings'] = pd.to_numeric(df['payout_winnings'], errors='coerce')
    df['transaction_date_time'] = pd.to_datetime(df['transaction_date_time'], format='%d %b %Y %I:%M %p')
    df['draw_eventdate_time'] = pd.to_datetime(df['draw_eventdate_time'], format='%d %b %Y %I:%M %p')

    def date_filter(df):
        if (df['type'] == 'Withdrawal') or (df['type'] == 'Deposit'):
            return df['transaction_date_time']
        else:
            return df['draw_eventdate_time']

    df['datetime'] = df.apply(date_filter, axis=1)

    df = df.drop(['channel'], axis=1)

    return df


def football_table(df):
    df = df.copy()
    df = df.loc[(df['type'] == 'Football') | (df['type'] == 'Deposit') | (df['type'] == 'Withdrawal')]
    df = df.sort_values(by=['datetime'])

    # df['returns']= df[['payout_winnings','amount']].max(axis=1)
    # df['returns']= np.where(df['payout_winnings']== 0,  df['returns']*-1, df['returns'])
    # df['returns'] = np.where(df['type'] == 'Withdrawal', df['returns'] * -1, df['returns'])

    def returns_filter(df):
        if (df['type'] == 'Football') and (df['status_receiptno'] == 'Settled'):
            return df['payout_winnings'] - df['amount']
        elif df['type'] == 'Withdrawal':
            return -df['amount']
        elif (df['type'] == 'Deposit'):
            return df['amount']

    df['returns'] = df.apply(returns_filter, axis=1)
    df['cum_sum'] = df['returns'].cumsum()
    df['perc_returns'] = df['returns'] / df['cum_sum'].shift(periods=1)

    # selection_details split into columns
    df['selection_details'] = df['selection_details'] \
        .apply(lambda x: re.sub('\\r|\&|\@|\([a-zA-Z]+\)', ' ', x).strip())
    df['live'] = np.where(df['selection_details'].str.contains('live'), 1, 0)

    df['league'] = df['selection_details'].str.split('-').str[0]
    df['match'] = df['selection_details'].str.split('-').str[1]
    df['home'] = df['match'].str.split('vs').str[0]
    df['away'] = df['match'].str.split('vs').str[1]
    df['bet_side'] = df['selection_details'].str.split('-').str[2]
    df[['league', 'match', 'bet_side', 'home', 'away']] = \
        df[['league', 'match', 'bet_side', 'home', 'away']].apply(lambda x: x.str.strip())
    df['sub_type'] = df['bet_side'].str.split(' ').str[0]
    df['bet_side'] = df['bet_side'].str.split(' ').str[1]
    df['odds'] = df['selection_details'].str.split(' ').str[-1]
    df['odds'] = pd.to_numeric(df['odds'], errors='coerce')
    df['imp_prob'] = 1 / df['odds']

    df['home'].fillna('Unknown', inplace=True)
    df['away'].fillna('Unknown', inplace=True)

    def bet_filter(df):
        if df['bet_side'] == 'Draw':
            return 'D'
        elif str(df.bet_side) in str(df.home):
            return 'H'
        else:
            return 'A'

    df['bet_side'] = df.apply(bet_filter, axis=1)

    df = df.drop(['selection_details'], axis=1)

    return df


def win_ratio_table(df):
    df = df.copy()
    df = df.loc[df['status_receiptno'] == 'Settled']
    df['win_ind'] = np.where(df['returns'] > 0, 1, 0)
    return df

def return_by_match_table(df):
    df = df.copy()
    df = df[['datetime', 'home', 'away', 'amount', 'payout_winnings', 'imp_prob', 'bet_side', 'win_ind', 'returns']]
    df['match_total_bet'] = df.groupby(['home', 'away', 'datetime'])['amount'].transform(np.sum)
    df['match_total_returns'] = df.groupby(['home', 'away', 'datetime'])['payout_winnings'].transform(np.sum)
    df['bet_per_match'] = df['amount'] / df['match_total_bet']
    df['imp_prob_weighted'] = np.round(df['imp_prob'] * df['bet_per_match'],2)
    df['date'] = df['datetime'].dt.date

    # groupby
    # aggregate bets for each match, since same event
    bet_side_one_hot = pd.get_dummies(df['bet_side'])
    df = pd.concat([df, bet_side_one_hot], axis=1)
    # df[['bet_side_A', 'bet_side_D', 'bet_side_H']] = df[['bet_side_A', 'bet_side_D', 'bet_side_H']]\
    df[['A', 'D', 'H']] = df[['A', 'D', 'H']].apply(lambda x: x * df['bet_per_match'])

    df = df.drop(['match_total_returns', 'match_total_bet', 'bet_per_match', 'imp_prob'], axis=1)
    df['num_of_bets'] = 1
    df = df.groupby(['home', 'away', 'date']).sum()

    df['frac_bets_win'] = df['win_ind'] / df['num_of_bets']
    df['agg_win_ind'] = np.where((df['payout_winnings'] - df['amount']) > 0, 1, 0)
    a = df[['A', 'D', 'H']]
    df = df.assign(side_agg=a.idxmax(axis=1), max_side_bet=a.max(axis=1))
    df['exact_frac_win'] = df['max_side_bet'] * df['agg_win_ind']
    df = df.reset_index()
    df['match_name'] = df['home'] + ' v ' + df['away']
    return df


def return_by_match_table_simple(df):
    df = df[['match_name', 'date', 'returns']]
    return df

# %%
def fetch_eg_csv(path):
    # note that file path starts from pools-dashboard directory
    df_list = tabula.read_pdf(path + "data/TransactionHistory.pdf", pages='all')
    df = pd.concat(df_list)
    return df

def convert_to_df(df_input):
    if df_input is not None:
        df = df_input.copy()
        df = process(df)
    return df


def df_to_match(df):
    if df is not None:
        df = football_table(df)
        df_wr = win_ratio_table(df)
        # wr= charts.win_ratio(df_wr)
        df_match = return_by_match_table(df_wr)
    return df_match

# %%
df = fetch_eg_csv(path)
# Out:
# WARNING:tabula.io:Got stderr: Nov 26, 2022 4:40:42 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Nov 26, 2022 4:40:42 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Nov 26, 2022 4:40:43 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# Nov 26, 2022 4:40:43 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Nov 26, 2022 4:40:43 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats

# %%
df.head()
# Out:
#   TRANSACTI\rON DATE &\rTIME                  TYPE CHANNEL  \
# 0      11 Aug 2022\r12:22 AM               Deposit       -
# 1      11 Aug 2022\r12:22 AM               Deposit       -
# 2      11 Aug 2022\r02:56 AM  TOTO\rTOTO\rOrdinary     Web
# 3      11 Aug 2022\r03:01 AM              Football     Web
# 4      11 Aug 2022\r03:01 AM              Football     Web
#
#                                  SELECTION / DETAILS    AMOUNT  \
# 0                              eNETS Transaction Fee   -$ 0.80
# 1                                    Deposit - eNETS  $ 110.80
# 2                       13,16,18,33,42,45\rSelf Pick    $ 1.00
# 3  English Premier\r(Outrights/Specials) - Englis...    $ 1.00
# 4  English Premier\r(Outrights/Specials) - Englis...    $ 6.00
#
#   DRAW /\rEVENT\rDATE &\rTIME       STATUS / RECEIPT\rNO. PAYOUT /\rWINNINGS
# 0                           -                           -                  -
# 1                           -                           -                  -
# 2       11 Aug 2022\r06:30 PM  Settled\rL/0111562/0000001             $ 0.00
# 3       29 May 2023\r12:00 AM   Placed\rO/0115148/0000089                  -
# 4       29 May 2023\r12:00 AM   Placed\rO/0115148/0000088                  -

# %%
df_clean = process(df)
df_match = df_to_match(df_clean)
df_match.head()
# Out:
#               home          away        date  amount  payout_winnings  \
# 0        Argentina  Saudi Arabia  2022-11-22     7.0             0.00
# 1          Arsenal        Fulham  2022-08-28     3.0             5.41
# 2          Arsenal     Liverpool  2022-10-09     2.0             0.00
# 3          Arsenal     Tottenham  2022-10-01     1.0             0.00
# 4  Atletico Madrid         Porto  2022-09-08     1.0             1.75
#
#    win_ind  returns  imp_prob_weighted    A    D    H  num_of_bets  \
# 0        0    -7.00               0.90  0.0  0.0  1.0            2
# 1        1     2.41               0.70  0.0  0.0  1.0            1
# 2        0    -2.00               0.37  0.5  0.5  0.0            2
# 3        0    -1.00               0.31  1.0  0.0  0.0            1
# 4        1     0.75               0.57  0.0  0.0  1.0            1
#
#    frac_bets_win  agg_win_ind side_agg  max_side_bet  exact_frac_win  \
# 0            0.0            0        H           1.0             0.0
# 1            1.0            1        H           1.0             1.0
# 2            0.0            0        A           0.5             0.0
# 3            0.0            0        A           1.0             0.0
# 4            1.0            1        H           1.0             1.0
#
#                  match_name
# 0  Argentina v Saudi Arabia
# 1          Arsenal v Fulham
# 2       Arsenal v Liverpool
# 3       Arsenal v Tottenham
# 4   Atletico Madrid v Porto

# %%
df_match_plot = df_match[['match_name', 'date', 'returns','imp_prob_weighted']]

# %%
import plotly.express as px
def scatter_returns(df, x, y):
    fig = px.scatter(df, x=x, y=y, hover_data=['match_name'],
                     title='Match returns over match day ')
    return fig

# %%
 
fig = px.scatter(df_match_plot, x=['date'], y='returns', hover_data=['match_name'], color='imp_prob_weighted',
                    title='Match returns over match day ', marginal_y='violin')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="14ff8c15-669c-4d10-8811-449e459786ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14ff8c15-669c-4d10-8811-449e459786ce")) {                    Plotly.newPlot(                        "14ff8c15-669c-4d10-8811-449e459786ce",                        [{"customdata":[["Argentina v Saudi Arabia"],["Arsenal v Fulham"],["Arsenal v Liverpool"],["Arsenal v Tottenham"],["Atletico Madrid v Porto"],["Augsburg v Bayern Munich"],["Bayern Munich v Monchengladbach"],["Bournemouth v Arsenal"],["Bournemouth v Tottenham"],["Brazil v Serbia"],["Brentford v Arsenal"],["Brentford v Everton"],["Brighton v Aston Villa"],["Brighton v Leicester"],["Brighton v Tottenham"],["Chelsea v Leicester"],["Chelsea v Tottenham"],["Crystal Palace v Aston Villa"],["Crystal Palace v Manchester Utd"],["England v Iran"],["England v USA"],["Everton v Manchester Utd"],["Everton v West Ham"],["France v Australia"],["Fulham v Manchester Utd"],["Getafe v Villarreal"],["Hertha Berlin v Freiburg"],["Holland v Ecuador"],["Juventus v Sassuolo"],["L City Sailors v Geylang"],["Lazio v Midtjylland"],["Leeds v Chelsea"],["Leicester v Crystal Palace"],["Liverpool v Crystal Palace"],["Liverpool v Manchester City"],["Liverpool v Southampton"],["Manchester City v Bournemouth"],["Manchester City v Crystal Palace"],["Manchester City v Manchester Utd"],["Manchester City v Nottingham"],["Manchester City v Tottenham"],["Manchester Utd v Arsenal"],["Manchester Utd v Tottenham"],["Newcastle v Crystal Palace"],["Newcastle v Manchester City"],["Nottingham v Aston Villa"],["Nottingham v Bournemouth"],["Nottingham v Brentford"],["Nottingham v Tottenham"],["Nottingham v West Ham"],["Portugal v Ghana"],["Real Madrid v Real Betis"],["S.League 2022 v Unknown"],["Sevilla v Athletic Bilbao"],["Southampton v Newcastle"],["Tottenham v Everton"],["Tottenham v Fulham"],["Tottenham v Leeds"],["Tottenham v Leicester"],["Tottenham v Liverpool"],["Tottenham v Newcastle"],["Tottenham v Sporting"],["Tottenham v Wolverhampton"],["Wales v Iran"],["West Ham v Tottenham"],["Wolverhampton v Arsenal"],["Wolverhampton v Brighton"],["Wolverhampton v Leicester"]],"hovertemplate":"value=%{x}<br>returns=%{y}<br>match_name=%{customdata[0]}<br>imp_prob_weighted=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.9,0.7,0.37,0.31,0.57,0.83,0.87,0.71,0.62,0.75,0.29,0.66,0.61,0.55,0.73,0.8200000000000001,0.34,0.44,0.3,0.8,0.64,0.59,0.75,0.8200000000000001,0.75,0.77,0.41000000000000003,0.8400000000000001,0.69,0.83,0.67,0.21,0.4,0.58,0.56,0.77,0.95,0.34,0.85,0.8,0.22,0.37,0.35000000000000003,0.85,0.73,0.4,0.77,0.65,0.84,0.56,0.8,0.95,0.92,0.75,0.54,0.7,0.77,0.62,0.7,0.33,0.41000000000000003,0.7000000000000001,0.75,0.51,0.53,0.69,0.51,0.89],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["2022-11-22","2022-08-28","2022-10-09","2022-10-01","2022-09-08","2022-10-20","2022-08-28","2022-08-21","2022-10-29","2022-11-25","2022-09-18","2022-08-27","2022-11-13","2022-09-04","2022-10-09","2022-08-27","2022-08-14","2022-08-20","2022-09-11","2022-11-21","2022-11-26","2022-10-10","2022-09-18","2022-11-23","2022-11-14","2022-08-28","2022-10-09","2022-11-26","2022-08-16","2022-09-04","2022-10-28","2022-08-21","2022-10-15","2022-08-16","2022-10-16","2022-11-12","2022-08-13","2022-08-27","2022-10-02","2022-09-01","2022-09-11","2022-09-04","2022-10-20","2022-09-03","2022-08-21","2022-10-11","2022-09-03","2022-11-05","2022-08-28","2022-08-14","2022-11-25","2022-09-03","2022-10-21","2022-10-09","2022-11-06","2022-10-16","2022-09-03","2022-11-12","2022-09-18","2022-11-07","2022-10-23","2022-10-27","2022-08-20","2022-11-25","2022-09-01","2022-11-13","2022-11-05","2022-10-23"],"x ...

# %%
# archie
def archie_score():
  df_archie= df_match[['match_name','imp_prob_weighted', 'win_ind']]
  num_bets = df_archie.shape[0]
  exp_win = df_archie['imp_prob_weighted'].sum()
  num_win_bets = df_archie[df_archie['win_ind'] ==1]['win_ind'].count()
  archie_score = num_bets*(num_win_bets - exp_win)**2/(exp_win * (num_bets - exp_win))

  if archie_score <= 0.3:
    chance = 0.58
  elif archie_score <= 0.5:
    chance = 0.48
  elif archie_score <= 1:
    chance = 0.32
  elif archie_score <= 1.5:
    chance = 0.22
  elif archie_score <= 2:
    chance = 0.16
  elif archie_score <= 2.5:
    chance = 0.11
  elif archie_score <= 3:
    chance = 0.08
  elif archie_score <= 4:
    chance = 0.05
  elif archie_score <= 5:
    chance = 0.03
  elif archie_score <= 8:
    chance = 0.01
  else:
    chance = 0

  return archie_score, chance

# %%
df_clean[df_clean['status_receiptno']=='Placed'].head()['selection_details']
# Out:
# 3    English Premier\r(Outrights/Specials) - Englis...
# 4    English Premier\r(Outrights/Specials) - Englis...
# 5    English Premier\r(Outrights/Specials) - Englis...
# 6    Spanish League\r(Outrights/Specials) - Spanish...
# 7    Italian League (Outrights/Specials) -\rItalian...
# Name: selection_details, dtype: object

# %%
def open_bets(df):
  df = df.copy()
  df = df.loc[(df['type'] == 'Football') | (df['type'] == 'Deposit') | (df['type'] == 'Withdrawal')]
  df = df.sort_values(by=['datetime'])
  df= df[df['status_receiptno']=='Placed']
  df = df[['draw_eventdate_time', 'selection_details','amount']]
  # make odds and win column
  df['odds'] = df[['selection_details']].apply(lambda x: x.str.split('@').str[-1])
  df['odds'] = pd.to_numeric(df['odds'])
  df['potential_win'] = df['odds'] * df['amount']
  # match column
  df['match'] = df['selection_details'] \
      .apply(lambda x: re.sub('\\r|\&|\@|\([a-zA-Z]+\)', ' ', x).strip()) 
  df['match'] = df['match'].str.split('-').str[1] + df['match'].str.split('-').str[2] 
  df['match'] =  df['match'].str.rsplit(' ',1).str[0]
  df= df.drop(columns=['selection_details'])
  # add totals
  df= df[['draw_eventdate_time','match','odds','amount','potential_win']]
  df['draw_eventdate_time'] = pd.to_datetime(df['draw_eventdate_time']).dt.normalize()
  df=df.reset_index(drop=True)
  return df

# %%
df_open = open_bets(df_clean)
df_open.head()
# Out:
#   draw_eventdate_time                                              match  \
# 0          2022-11-27                    France vs Denmark  1X2 France
# 1          2022-11-27               Argentina vs Mexico  1X2 Argentina
# 2          2022-11-27                   Japan vs Costa Rica  1X2 Japan
# 3          2022-11-29      W Cup: Group A Winner  Group Winner Holland
# 4          2022-11-29   W Cup: Group A Qualifier  Group Qualifier Hol...
#
#    odds  amount  potential_win
# 0  1.63     2.0           3.26
# 1  1.48     3.0           4.44
# 2  1.35     2.0           2.70
# 3  1.42     1.0           1.42
# 4  1.14     5.0           5.70

# %%
df_wr = win_ratio_table(df_clean)
df_wr.head()
